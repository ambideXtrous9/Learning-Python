# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
# Create a meshgrid of x1 and x2 values
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-1, 1, 100)
X1, X2 = np.meshgrid(x1, x2)

# Calculate the function values based on the different regions
Z = np.abs(X1) + np.abs(X2)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='viridis', alpha=0.8)

# Set axis labels
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('|x1| + |x2|')

# Show the plot
plt.show()

# %%
# Create a meshgrid of x1 and x2 values
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-1, 1, 100)
X1, X2 = np.meshgrid(x1, x2)

# Calculate the function values based on the different regions
Z = np.abs(X1) + np.abs(X2)

# Create a contour plot
plt.contour(X1, X2, Z, levels=np.linspace(Z.min(), Z.max(), 20), cmap='viridis')

# Set axis labels
plt.xlabel('x1')
plt.ylabel('x2')

# Show the plot
plt.title('|x1| + |x2| Contour Plot')
plt.show()

# %%
# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(1, 7, 100)
w1_vals = np.linspace(2, 5, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Calculate the MSE values based on the linear regression model
m = len(y)
MSE = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        MSE[i, j] = np.sum(errors**2) / (2 * m)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W0, W1, MSE, cmap='viridis', alpha=0.8)

# Set axis labels
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('MSE')

# Show the plot
plt.title('MSE for y = w0 + w1*x1')
plt.show()

# %%
# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(1, 7, 100)
w1_vals = np.linspace(2, 5, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Calculate the MSE values based on the linear regression model
m = len(y)
MSE = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        MSE[i, j] = np.sum(errors**2) / (2 * m)

# Create a 3D plot with a better view
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W0, W1, MSE, cmap='viridis', alpha=0.8)

# Set axis labels
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('MSE')

# Set the view for a better perspective
ax.view_init(elev=25, azim=-30)  # Adjust the viewing angle

# Show the plot
plt.title('MSE for y = w0 + w1*x1')
plt.show()

# %%
# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(1, 7, 100)
w1_vals = np.linspace(2, 5, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Calculate the MSE values based on the linear regression model
m = len(y)
MSE = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        MSE[i, j] = np.sum(errors**2) / (2 * m)

# Create a contour plot
plt.contour(W0, W1, MSE, levels=np.logspace(-1, 2, 50), cmap='viridis')

# Set axis labels
plt.xlabel('w0')
plt.ylabel('w1')

# Show the plot
plt.title('MSE Contour Plot for y = w0 + w1*x1')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(-5, 10, 100)
w1_vals = np.linspace(-5, 10, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)


# Calculate the regularized loss values based on the linear regression model
m = len(y)
regularized_loss = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        mse_term = np.sum(errors**2) / (2 * m)
        regularized_loss[i, j] = mse_term 

# Create a 3D surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W0, W1, regularized_loss, cmap='viridis', alpha=0.7)

# Set axis labels
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('Regularized Loss')

# Set the view for a better perspective
ax.view_init(elev=40, azim=-40)

# Show the plot
plt.title('Regularized Loss Surface Plot for y = w0 + w1*x1')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(-5, 10, 100)
w1_vals = np.linspace(-5, 10, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Regularization strength (lambda)
lambda_val = 0.8

# Calculate the regularized loss values based on the linear regression model
m = len(y)
regularized_loss = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        mse_term = np.sum(errors**2) / (2 * m)
        regularized_loss[i, j] = mse_term 

# Create a contour plot
plt.contour(W0, W1, regularized_loss, levels=np.logspace(-1, 2, 50), cmap='viridis')

# Set axis labels
plt.xlabel('w0')
plt.ylabel('w1')

# Show the plot
plt.title('MSE Contour Plot for y = w0 + w1*x1')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(-5, 10, 100)
w1_vals = np.linspace(-5, 10, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Regularization strength (lambda)
lambda_val = 0.8

# Calculate the regularized loss values based on the linear regression model
m = len(y)
regularized_loss = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        mse_term = np.sum(errors**2) / (2 * m)
        regularization_term = (lambda_val / 2) * (W0[i, j]**2 + W1[i, j]**2)
        regularized_loss[i, j] = mse_term + regularization_term

# Create a 3D surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W0, W1, regularized_loss, cmap='viridis', alpha=0.7)

# Set axis labels
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('Regularized Loss')

# Set the view for a better perspective
ax.view_init(elev=40, azim=-40)

# Show the plot
plt.title('Regularized Loss Surface Plot for y = w0 + w1*x1')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data
np.random.seed(42)
X1 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X1 + np.random.randn(100, 1)

# Create a meshgrid of w0 and w1 values
w0_vals = np.linspace(-5, 10, 100)
w1_vals = np.linspace(-5, 10, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Regularization strength (lambda)
lambda_val = 0.8

# Calculate the regularized loss values based on the linear regression model
m = len(y)
regularized_loss = np.zeros_like(W0)

for i in range(len(w0_vals)):
    for j in range(len(w1_vals)):
        predictions = W0[i, j] + W1[i, j] * X1
        errors = predictions - y
        mse_term = np.sum(errors**2) / (2 * m)
        regularization_term = (lambda_val / 2) * (W0[i, j]**2 + W1[i, j]**2)
        regularized_loss[i, j] = mse_term + regularization_term

# Create a contour plot
plt.contour(W0, W1, regularized_loss, levels=np.logspace(-1, 2, 100), cmap='viridis')

# Set axis labels
plt.xlabel('w0')
plt.ylabel('w1')

# Show the plot
plt.title('MSE Contour Plot for y = w0 + w1*x1')
plt.show()

# %%
# Create a meshgrid of x1 and x2 values
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-1, 1, 100)
X1, X2 = np.meshgrid(x1, x2)

# Calculate the function values based on the different regions
Z = (X1**2) + (X2**2)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='viridis', alpha=0.8)

# Set axis labels
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('X1^2 + x2^2')

# Show the plot
plt.show()

# %%
# Create a meshgrid of x1 and x2 values
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-1, 1, 100)
X1, X2 = np.meshgrid(x1, x2)

# Calculate the function values based on the different regions
Z = (X1**2) + (X2**2)

# Create a contour plot
plt.contour(X1, X2, Z, levels=np.linspace(Z.min(), Z.max(), 100), cmap='viridis')

# Set axis labels
plt.xlabel('x1')
plt.ylabel('x2')

# Show the plot
plt.title('|x1| + |x2| Contour Plot')
plt.show()
